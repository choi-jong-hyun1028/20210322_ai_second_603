# %%
la=[]#단어 리스트
ca=[]#카운트 리스트
for i in c:
    if i in la:
        continue #단어 중복 방지
    if(max < c.count(i)):
        max = c.count(i)
    la.append(i)
    ca.append(c.count(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af5d776ec904> in <module>
#       1 la=[]#단어 리스트
#       2 ca=[]#카운트 리스트
# ----> 3 for i in c:
#       4     if i in la:
#       5         continue
#
# NameError: name 'c' is not defined

# %%
a= 'apple'
b= 'banana'
print(a,b)
print(a+" "+b)
# Out:
# apple banana
# apple banana

# %%
number_list = [number for number in range(1,6)]
number_list
a_list = [number for number in range(1,6) if number % 2 ==1]
a_list
rows = range(1,4)
cols = range(1,3)
cells = [(row,col) for row in rows for col in ]
# Out:
# [1, 3, 5]

# %%
# year_list = [1980,1981,1982,1983,1984,1985] #7.1
year_lists = [x for X in range(1980,1986)]
print(year_lists)
# print(year_lists[3]) #7.2
# print(year_lists[0]) #7.3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e9fd77412881> in <module>
#       1 # year_list = [1980,1981,1982,1983,1984,1985] #7.1
# ----> 2 year_lists = [x for X in range(1980,1986)]
#       3 print(year_lists)
#       4 # print(year_lists[3]) #7.2
#       5 # print(year_lists[0]) #7.3
#
# <ipython-input-28-e9fd77412881> in <listcomp>(.0)
#       1 # year_list = [1980,1981,1982,1983,1984,1985] #7.1
# ----> 2 year_lists = [x for X in range(1980,1986)]
#       3 print(year_lists)
#       4 # print(year_lists[3]) #7.2
#       5 # print(year_lists[0]) #7.3
#
# NameError: name 'x' is not defined

# %%
number_list = [number for number in range(10) if number % 2 == 0] #7.10
print(type(number_list)) 
print(number_list)
# Out:
# <class 'list'>
# [0, 2, 4, 6, 8]

# %%
things = ["mozzarella","cinderella","salmonella"] #7.4
print(type(things)) #7.6
for ds in things:
    print(things[0].upper())
# Out:
# <class 'list'>
# MOZZARELLA
# MOZZARELLA
# MOZZARELLA

# %%
surprise = ["Groucho","Chico","Harpo"] #7.8
print(surprise[2].lower()) #7.9
print(surprise[2].lower()[::-1].capitalize())
# Out:
# harpo
# Oprah

# %%
#7.11
start1 = ["fee","fie","foe"]
rhymes = [
    ('flop','get a mop'),
    ('fope','turn the rope'),
    ('fa','get your ma'),
    ('fudge','call the judge'),
    ('fat','pet the cat'),
    ('fog','walk the dog'),
    ("fun","say we're done"),
]
start2 = "Someone better"
for a in start1:   #7.11 (1)
    print(a.capitalize()+"!"+" ")    
for b in rhymes[0]:
    print(b.capitalize()+"!")
    
print(start2+" ") #7.11(2)
for c in rhymes[1]:
    print(c+".")
# Out:
# Fee!
# Fie!
# Foe!
# Flop!
# Get a mop!
# Someone better
# fope.
# turn the rope.

# %%
toa = ("al","ba")
print(dict(toa))
asd = ["sd","gh","rt"]
print(dict(asd))
tol = (['a','b'],['c','b'],['e','g'])
print(dict(tol))
print(type(dict(tol)))
acme_customer = {'first': 'while','middle':'E'}
acme_customer
sdfed = {
    "sadas":"asdsafasfasfasfasfasfafsafa",
    "djfikld":"sjmjlsjkleiijilo;ldf",
    "mjko;as":"kljksjklfjaklj;lasfasf"
        }
type(sdfed)
# Out:
# {'a': 'l', 'b': 'a'}
# {'s': 'd', 'g': 'h', 'r': 't'}
# {'a': 'b', 'c': 'b', 'e': 'g'}
# <class 'dict'>
# dict

# %%
pythons = {
    'chapman':'Garasds',
    'Cleese':'asdadadasd',
    'Idle':'Garaasdasdadsds',
    'Jones':'Garasdasasds',
    'Palin':'gfgfgds',
}
pythons['grfcde'] = 'frsdsr'
pythons['grfcde'] = 'aaaaaaaaaa'
print(pythons)
pythons.get('Idled',"no")
print(pythons.keys())
print(pythons.values())
len(pythons)
# Out:
# {'chapman': 'Garasds', 'Cleese': 'asdadadasd', 'Idle': 'Garaasdasdadsds', 'Jones': 'Garasdasasds', 'Palin': 'gfgfgds', 'grfcde': 'aaaaaaaaaa'}
# dict_keys(['chapman', 'Cleese', 'Idle', 'Jones', 'Palin', 'grfcde'])
# dict_values(['Garasds', 'asdadadasd', 'Garaasdasdadsds', 'Garasdasasds', 'gfgfgds', 'aaaaaaaaaa'])
# 6
